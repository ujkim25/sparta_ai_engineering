# %% [markdown]
# <a href="https://colab.research.google.com/github/ujkim25/sparta_ai_engineering/blob/main/%EC%8A%A4%ED%8C%8C%EB%A5%B4%ED%83%80_2025_09_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("sample.txt", "w", encoding="utf-8") as file:
    file.write("안녕하세요\n")
    file.write('파이썬 입출력 예제입니다')
    file.write('여러 줄을 작성할 수 있습니다')

# %%
with open("sample.txt", "r", encoding="utf-8") as file:
    content = file.read()

# %%
content
# Out:
# '안녕하세요\n파이썬 입출력 예제입니다여러 줄을 작성할 수 있습니다'

# %%
with open("sample.txt", "r", encoding="utf-8") as file:
    content = file.readlines()

# %%
content
# Out:
# ['안녕하세요\n', '파이썬 입출력 예제입니다여러 줄을 작성할 수 있습니다']

# %%
with open("sample.txt", "r") as file:
    for line_num, line in enumerate(file, 1): # 인덱스가 1부터 시작하도록 해줘
        print(f"{line_num}: {line.strip()}") # 문자열의 양 끝에 있는 공백 제거
# Out:
# 1: 안녕하세요
# 2: 파이썬 입출력 예제입니다여러 줄을 작성할 수 있습니다

# %%
import json

# %%
data = {
    "name":"김철수",
    "age":25,
    "hobbies":["독서","영화감상"]
}

# %%
with open("data.json", "w") as file:
    json.dump(data, file, ensure_ascii=False, indent=4)
# 파일로서의 json

# %%
with open("data.json", "r") as file:
    loaded_data = json.load(file)

# %%
loaded_data
# Out:
# {'name': '김철수', 'age': 25, 'hobbies': ['독서', '영화감상']}

# %%
json_string = json.dumps(data, ensure_ascii=False, indent=4)
# 컴퓨터끼리 소통하기 위한 json

# !!! 파일로서의 json과 컴퓨터끼리 소통하기 위한 json은 다르다

# %%
json_string
# Out:
# '{\n    "name": "김철수",\n    "age": 25,\n    "hobbies": [\n        "독서",\n        "영화감상"\n    ]\n}'

# %%
parsed_data = json.loads(json_string)

# %%
parsed_data
# Out:
# {'name': '김철수', 'age': 25, 'hobbies': ['독서', '영화감상']}

# %%
data_list = [{
    "name":"김철수",
    "age":25
},
    {
    "name":"김우진",
    "age":27
}]

# %%
with open("sample.json", "w") as file:
    json.dump(data_list, file, ensure_ascii=False, indent=4)

# %%
with open("sample.jsonl", 'w') as file:
    for data in data_list:
        file.write(json.dumps(data, ensure_ascii=False) + '\n')

# %%
data_list = []

with open("sample.jsonl", "r") as file:
    for line in file:
        data = json.loads(line)
        data_list.append(data)

# %%
data_list
# Out:
# [{'name': '김철수', 'age': 25}, {'name': '김우진', 'age': 27}]

# %% [markdown]
# json 객체를 파이썬 딕셔너리로 변환 : loads

# %% [markdown]
# json 파일을 읽고 쓸때: dump, load
#
# 파이썬 dict -> json 객체: dumps
# json 객체 -> 파이썬 dict: loads
#
# json 파일이랑 json 객체가 다르다

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y1 = np.sin(x)
y2 = np.cos(x)

# %%
y1
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
y2
# Out:
# array([ 1.        ,  0.99490282,  0.97966323,  0.95443659,  0.91948007,
#         0.87515004,  0.8218984 ,  0.76026803,  0.69088721,  0.61446323,
#         0.53177518,  0.44366602,  0.35103397,  0.25482335,  0.15601496,
#         0.0556161 , -0.04534973, -0.14585325, -0.24486989, -0.34139023,
#        -0.43443032, -0.52304166, -0.60632092, -0.68341913, -0.75355031,
#        -0.81599952, -0.87013012, -0.91539031, -0.95131866, -0.97754893,
#        -0.9938137 , -0.99994717, -0.9958868 , -0.981674  , -0.95745366,
#        -0.92347268, -0.88007748, -0.82771044, -0.76690542, -0.69828229,
#        -0.6225406 , -0.54045251, -0.45285485, -0.36064061, -0.26474988,
#        -0.16616018, -0.06587659,  0.03507857,  0.13567613,  0.23489055,
#         0.33171042,  0.4251487 ,  0.51425287,  0.59811455,  0.67587883,
#         0.74675295,  0.8100144 ,  0.86501827,  0.91120382,  0.94810022,
#         0.97533134,  0.99261957,  0.99978867,  0.99676556,  0.98358105,
# ...

# %%
plt.figure(figsize=(10,6)) # 그림 그리는데 필요한 도화지를 만들겠다
plt.plot(x,y1,color="blue", linestyle='-', label="sin(x)")
plt.plot(x,y2,color="red", linestyle="--", label="cos(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("sin and cos function")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.show()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# 판다스는 컬럼 단위(시리즈)로 데이터를 저장
# 시리즈를 여러개 묶어서 2차원 형태의 표 형태가 데이터프레임

# %%
import pandas as pd
import numpy as np

# %%
data = {
    '이름': ['김철수', '이영희', '박민수', '최지영', '정다은'],
    '나이': [25, 30, 35, 28, 32],
    '도시': ['서울', '부산', '대구', '인천', '광주'],
    '점수': [85, 92, 78, 88, 95]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 3  최지영  28  인천  88
# 4  정다은  32  광주  95

# %%
type(df) #데이터프레임도 클래스이다
# Out:
# pandas.core.frame.DataFrame

# %%
print(df)
print(f"DataFrame 크기: {df.shape}")
print(f"컬럼명: {df.columns}")
# Out:
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 3  최지영  28  인천  88
# 4  정다은  32  광주  95
# DataFrame 크기: (5, 4)
# 컬럼명: Index(['이름', '나이', '도시', '점수'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      5 non-null      object
#  1   나이      5 non-null      int64
#  2   도시      5 non-null      object
#  3   점수      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None

# %%
print(df.describe())
# Out:
#               나이         점수
# count   5.000000   5.000000
# mean   30.000000  87.600000
# std     3.807887   6.580274
# min    25.000000  78.000000
# 25%    28.000000  85.000000
# 50%    30.000000  88.000000
# 75%    32.000000  92.000000
# max    35.000000  95.000000

# %%
df["나이"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    28
# 4    32
# Name: 나이, dtype: int64

# %%
type(df["나이"])
# Out:
# pandas.core.series.Series

# %%
df[["나이", "이름"]]
# Out:
#    나이   이름
# 0  25  김철수
# 1  30  이영희
# 2  35  박민수
# 3  28  최지영
# 4  32  정다은

# %%
df["나이"] >= 30
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: 나이, dtype: bool

# %%
df[df["나이"] >= 30]
# Out:
#     이름  나이  도시  점수
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 4  정다은  32  광주  95

# %%
df[df["도시"] == '부산']
# Out:
#     이름  나이  도시  점수
# 1  이영희  30  부산  92

# %%
df[df['도시'] == '서울'][['이름', '점수']] # 컬럼 명을 여러개 할 때는 리스트로 넣어준다
# Out:
#     이름  점수
# 0  김철수  85

# %%
data2 = {
    '이름': ['김철수', '이영희', '박민수', '최지영', '정다은'],
    '나이': [25, 30, 35, None, 32],
    '도시': ['서울', '부산', '대구', '인천', '광주'],
    '점수': [85, 92, 78, 88, 95]
}

# %%
df_2 = pd.DataFrame(data2)

# %%
df_2
# Out:
#     이름    나이  도시  점수
# 0  김철수  25.0  서울  85
# 1  이영희  30.0  부산  92
# 2  박민수  35.0  대구  78
# 3  최지영   NaN  인천  88
# 4  정다은  32.0  광주  95

# %%
df_2['나이'].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: 나이, dtype: bool

# %%
df[df_2['나이'].notnull()]
# Out:
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 4  정다은  32  광주  95

# %%
df.to_csv('students.csv')

# %%
df_from_csv = pd.read_csv("students.csv")

# %%
df_from_csv
# Out:
#    Unnamed: 0   이름  나이  도시  점수
# 0           0  김철수  25  서울  85
# 1           1  이영희  30  부산  92
# 2           2  박민수  35  대구  78
# 3           3  최지영  28  인천  88
# 4           4  정다은  32  광주  95

# %%
# !pip install openpyxl

# %%
df.to_excel("students.xlsx")

# %%
df_from_excel = pd.read_excel("students.xlsx")

# %%
df_from_excel
# Out:
#    Unnamed: 0   이름  나이  도시  점수
# 0           0  김철수  25  서울  85
# 1           1  이영희  30  부산  92
# 2           2  박민수  35  대구  78
# 3           3  최지영  28  인천  88
# 4           4  정다은  32  광주  95

# %%
df
# Out:
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 3  최지영  28  인천  88
# 4  정다은  32  광주  95

# %%
new_student = pd.DataFrame({
    "이름":["홍길동"],
    "나이":[34],
    "도시":["강릉"],
    "점수":[97]
})

# %%
new_student
# Out:
#     이름  나이  도시  점수
# 0  홍길동  34  강릉  97

# %% [markdown]
# df를 새로 만들고 기존 df랑 합친다
# 두 개의 df의 열 이름이 같아야 한다

# %%
df_updated = pd.concat([df, new_student], ignore_index=True)

# %%
df_updated
# Out:
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# 1  이영희  30  부산  92
# 2  박민수  35  대구  78
# 3  최지영  28  인천  88
# 4  정다은  32  광주  95
# 5  홍길동  34  강릉  97

# %%
for key, each_df in df_updated.groupby("도시"):
    print("="*30)
    print(key)
    print(each_df)
# Out:
# ...
# 강릉
#     이름  나이  도시  점수
# 5  홍길동  34  강릉  97
# ...
# 광주
#     이름  나이  도시  점수
# 4  정다은  32  광주  95
# ...
# 대구
#     이름  나이  도시  점수
# 2  박민수  35  대구  78
# ...
# 부산
#     이름  나이  도시  점수
# 1  이영희  30  부산  92
# ...
# 서울
#     이름  나이  도시  점수
# 0  김철수  25  서울  85
# ...
# 인천
#     이름  나이  도시  점수
# 3  최지영  28  인천  88

# %%
# df.to_excel("students.xlsx")

with pd.ExcelWriter("student_data.xlsx", engine="openpyxl") as writer:
    df_updated.to_excel(writer, sheet_name="전체학생", index=False)
# with 키워드를 통해 파일을 한번 열게됨 그렇기 때문에 추가 작업이 수월하다

# %%
employee_data = {
    '이름': ['김철수', '이영희', '박민수', '최지우', '정수진'],
    '나이': [25, 28, 23, 30, 27],
    '부서': ['영업', '마케팅', '개발', '개발', '인사'],
    '급여': [3000, 3500, 2800, 4000, 3300]
}

# %%
df_employees = pd.DataFrame(employee_data)

# %%
df_employees
# Out:
#     이름  나이   부서    급여
# 0  김철수  25   영업  3000
# 1  이영희  28  마케팅  3500
# 2  박민수  23   개발  2800
# 3  최지우  30   개발  4000
# 4  정수진  27   인사  3300

# %%
df_employees[:3]
# Out:
#     이름  나이   부서    급여
# 0  김철수  25   영업  3000
# 1  이영희  28  마케팅  3500
# 2  박민수  23   개발  2800

# %%
df_employees.iloc[2:4]
# Out:
#     이름  나이  부서    급여
# 2  박민수  23  개발  2800
# 3  최지우  30  개발  4000

# %%
df_employees.loc[2:4]
# Out:
#     이름  나이  부서    급여
# 2  박민수  23  개발  2800
# 3  최지우  30  개발  4000
# 4  정수진  27  인사  3300

# %%
df_indexed = pd.DataFrame(employee_data, index=['사원1', '사원2', '사원3', '사원4', '사원5'])

# %%
df_indexed
# Out:
#       이름  나이   부서    급여
# 사원1  김철수  25   영업  3000
# 사원2  이영희  28  마케팅  3500
# 사원3  박민수  23   개발  2800
# 사원4  최지우  30   개발  4000
# 사원5  정수진  27   인사  3300

# %%
df_indexed.iloc[2:4]
# index를 보지 않고 순서를 기준으로 가져오기 때문에 0~5여도 된다
# Out:
#       이름  나이  부서    급여
# 사원3  박민수  23  개발  2800
# 사원4  최지우  30  개발  4000

# %%
df_indexed.loc[2:4] # index를 보고 가져오기 때문에 사원1~5가 아니여서 틀림
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3632153803.py in <cell line: 0>()
# ----> 1 df_indexed.loc[2:4]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1409         if isinstance(key, slice):
#    1410             self._validate_key(key, axis)
# -> 1411             return self._get_slice_axis(key, axis=axis)
#    1412         elif com.is_bool_indexer(key):
# ...

# %%
df_indexed.loc["사원3"]
# Out:
# 이름     박민수
# 나이      23
# 부서      개발
# 급여    2800
# Name: 사원3, dtype: object

# %%
(df_employees["부서"]=="개발") & (df_employees["나이"]>=25)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
df_employees["부서"]=="개발"
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: 부서, dtype: bool

# %%
df_employees["나이"]>=25
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: 나이, dtype: bool

# %%
df_employees[(df_employees["부서"]=="개발") & (df_employees["나이"]>=25)]
# Out:
#     이름  나이  부서    급여
# 3  최지우  30  개발  4000

# %%
df_indexed
# Out:
#       이름  나이   부서    급여
# 사원1  김철수  25   영업  3000
# 사원2  이영희  28  마케팅  3500
# 사원3  박민수  23   개발  2800
# 사원4  최지우  30   개발  4000
# 사원5  정수진  27   인사  3300

# %%
df_indexed['월급'] = df_indexed['급여']/12

# %%
df_indexed['급여']/12
# pandas series는 numpy 배열로 만들어짐 -> 모든 원소를 한번에
# Out:
# 사원1    250.000000
# 사원2    291.666667
# 사원3    233.333333
# 사원4    333.333333
# 사원5    275.000000
# Name: 급여, dtype: float64

# %%
df_indexed
# Out:
#       이름  나이   부서    급여          월급
# 사원1  김철수  25   영업  3000  250.000000
# 사원2  이영희  28  마케팅  3500  291.666667
# 사원3  박민수  23   개발  2800  233.333333
# 사원4  최지우  30   개발  4000  333.333333
# 사원5  정수진  27   인사  3300  275.000000

# %%
df_indexed.drop("급여", axis=1)
# inplace 연산이 아님
# Out:
#       이름  나이   부서          월급
# 사원1  김철수  25   영업  250.000000
# 사원2  이영희  28  마케팅  291.666667
# 사원3  박민수  23   개발  233.333333
# 사원4  최지우  30   개발  333.333333
# 사원5  정수진  27   인사  275.000000

# %%
df_indexed
# Out:
#       이름  나이   부서    급여          월급
# 사원1  김철수  25   영업  3000  250.000000
# 사원2  이영희  28  마케팅  3500  291.666667
# 사원3  박민수  23   개발  2800  233.333333
# 사원4  최지우  30   개발  4000  333.333333
# 사원5  정수진  27   인사  3300  275.000000

# %%
df_indexed_2 = df_indexed.drop("급여", axis=1)

# %%
df_indexed_2
# Out:
#       이름  나이   부서          월급
# 사원1  김철수  25   영업  250.000000
# 사원2  이영희  28  마케팅  291.666667
# 사원3  박민수  23   개발  233.333333
# 사원4  최지우  30   개발  333.333333
# 사원5  정수진  27   인사  275.000000

# %%
df_copied_2 = df_indexed.copy()

# %%
id(df_copied_2) # id가 바뀐다
# Out:
# 139748583480336

# %%
id(df_indexed)
# Out:
# 139748517496736

# %% [markdown]
# 오리지널 데이터를 보존하기 위해 inplace 연산은 사용하지말고 변수2 = 변수.~ 이렇게 하자|

# %%
df_employees.sort_values(by='나이')
# Out:
#     이름  나이   부서    급여
# 2  박민수  23   개발  2800
# 0  김철수  25   영업  3000
# 4  정수진  27   인사  3300
# 1  이영희  28  마케팅  3500
# 3  최지우  30   개발  4000

# %%
df_employees.sort_values(by='나이').reset_index()
# Out:
#    index   이름  나이   부서    급여
# 0      2  박민수  23   개발  2800
# 1      0  김철수  25   영업  3000
# 2      4  정수진  27   인사  3300
# 3      1  이영희  28  마케팅  3500
# 4      3  최지우  30   개발  4000

# %%
df_employees.sort_values(by='나이').reset_index(drop=True)
# Out:
#     이름  나이   부서    급여
# 0  박민수  23   개발  2800
# 1  김철수  25   영업  3000
# 2  정수진  27   인사  3300
# 3  이영희  28  마케팅  3500
# 4  최지우  30   개발  4000

# %%
df_tmp = df_employees

# %%
df_tmp.sort_index()
# Out:
#     이름  나이   부서    급여
# 0  김철수  25   영업  3000
# 1  이영희  28  마케팅  3500
# 2  박민수  23   개발  2800
# 3  최지우  30   개발  4000
# 4  정수진  27   인사  3300

# %%
df_employees
# Out:
#     이름  나이   부서    급여
# 0  김철수  25   영업  3000
# 1  이영희  28  마케팅  3500
# 2  박민수  23   개발  2800
# 3  최지우  30   개발  4000
# 4  정수진  27   인사  3300

# %%
target_depts = ['개발', '마케팅']

# %%
df_employees['부서'].isin(target_depts)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: 부서, dtype: bool

# %%
data_with_missing = {
    '이름': ['김철수', '이영희', '박민수', '최지우', '정수진'],
    '나이': [25, np.nan, 30, 28, np.nan],
    '급여': [3000, 3500, np.nan, 4000, 3200],
    '부서': ['영업', '마케팅', np.nan, '개발', '인사']
}

# %%
df_missing=pd.DataFrame(data_with_missing)

# %%
df_missing.isnull()
# Out:
#       이름     나이     급여     부서
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False

# %%
df_missing.isnull().sum()
# Out:
# 이름    0
# 나이    2
# 급여    1
# 부서    1
# dtype: int64

# %%
df_missing.dropna()
# Out:
#     이름    나이      급여  부서
# 0  김철수  25.0  3000.0  영업
# 3  최지우  28.0  4000.0  개발

# %%
df_missing.dropna(subset=['급여'])
# Out:
#     이름    나이      급여   부서
# 0  김철수  25.0  3000.0   영업
# 1  이영희   NaN  3500.0  마케팅
# 3  최지우  28.0  4000.0   개발
# 4  정수진   NaN  3200.0   인사

# %%
df_missing.fillna("TEMP")
# Out:
#     이름    나이      급여    부서
# 0  김철수  25.0  3000.0    영업
# 1  이영희  TEMP  3500.0   마케팅
# 2  박민수  30.0    TEMP  TEMP
# 3  최지우  28.0  4000.0    개발
# 4  정수진  TEMP  3200.0    인사

# %%
df_missing.fillna(
    {
        "나이":df_missing["나이"].mean(), # null 값을 제외한 값들의 mean
        "급여":df_missing["급여"].median(),
        "부서":"미정"
    }
)
# Out:
#     이름         나이      급여   부서
# 0  김철수  25.000000  3000.0   영업
# 1  이영희  27.666667  3500.0  마케팅
# 2  박민수  30.000000  3350.0   미정
# 3  최지우  28.000000  4000.0   개발
# 4  정수진  27.666667  3200.0   인사

# %%
df_missing.['나이'].
